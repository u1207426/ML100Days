# %% [markdown]
# # 範例 : (Kaggle)房價預測
# ***
# - 以下用房價預測資料, 觀察均值編碼的效果

# %% [markdown]
# # [教學目標]
# - 以下用房價預測資料, 觀察均值編碼的效果

# %% [markdown]
# # [範例重點]
# - 觀察標籤編碼與均值編碼, 在特徵數量 / 線性迴歸分數 / 線性迴歸時間上, 分別有什麼影響 (In[3], Out[3], In[4], Out[4])
# - 觀察標籤編碼與均值編碼, 在特徵數量 / 梯度提升樹分數 / 梯度提升樹時間上, 分別有什麼影響 (In[5], Out[5], In[6], Out[6])

# %%
# 做完特徵工程前的所有準備
import pandas as pd
import numpy as np
import copy, time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder

data_path = 'data/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')
df_test = pd.read_csv(data_path + 'house_test.csv.gz')

train_Y = np.log1p(df_train['SalePrice'])
ids = df_test['Id']
df_train = df_train.drop(['Id', 'SalePrice'] , axis=1)
df_test = df_test.drop(['Id'] , axis=1)
df = pd.concat([df_train,df_test])
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0       2    2008        WD         Normal
# 1         NaN       0       5    2007        WD         Normal
# 2         NaN       0       9    2008        WD         Normal
# 3         NaN       0       2    2006        WD        Abnorml
# 4         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
#只取類別值 (object) 型欄位, 存於 object_features 中
object_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'object':
        object_features.append(feature)
print(f'{len(object_features)} Numeric Features : {object_features}\n')

# 只留類別型欄位
df = df[object_features]
df = df.fillna('None')
train_num = train_Y.shape[0]
df.head()
# Out:
# 43 Numeric Features : ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave  None      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
#   PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# 0          Y   None  None        None       WD        Normal
# 1          Y   None  None        None       WD        Normal
# 2          Y   None  None        None       WD        Normal
# 3          Y   None  None        None       WD       Abnorml
# 4          Y   None  None        None       WD        Normal
#
# [5 rows x 43 columns]

# %%
# 對照組 : 標籤編碼 + 線性迴歸
df_temp = pd.DataFrame()
for c in df.columns:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
train_X = df_temp[:train_num]
estimator = LinearRegression()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, train_X, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.6615606866851305
# time : 0.03506803512573242 sec

# %%
data = pd.concat([df[:train_num], train_Y], axis=1)
data.head()
group=data.groupby("LotShape")
mean_df=data.groupby("LotShape")["SalePrice"].mean().reset_index()
mean_df.columns=["LotShape","LotShape_mean"]
print(list(group))#看一下groupby後長什麼樣子
print(list(group["SalePrice"]))
print(data.groupby("LotShape")["SalePrice"].mean())
print(data.groupby("LotShape")["SalePrice"].mean().reset_index())
print(mean_df)
# Out:
# [('IR1',      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 2          RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave  None      IR1         Lvl    AllPub       FR2       Gtl
# 5          RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 7          RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1429       RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 1431       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 1433       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 1440       RL   Pave  None      IR1         Bnk    AllPub    Inside       Mod
# 1446       RL   Pave  None      IR1         Lvl    AllPub   CulDSac       Gtl
#
#      Neighborhood Condition1  ... GarageFinish GarageQual GarageCond  \
# 2         CollgCr       Norm  ...          RFn         TA         TA
# 3         Crawfor       Norm  ...          Unf         TA         TA
# 4         NoRidge       Norm  ...          RFn         TA         TA
# 5         Mitchel       Norm  ...          Unf         TA         TA
# 7          NWAmes       PosN  ...          RFn         TA         TA
# ...           ...        ...  ...          ...        ...        ...
# 1429       NWAmes       Norm  ...          Fin         TA         TA
# 1431      NPkVill       Norm  ...          RFn         TA         TA
# 1433      Gilbert       Norm  ...          Fin         TA         TA
# 1440      Crawfor       Norm  ...          Fin         TA         TA
# 1446      Mitchel       Norm  ...          Unf         TA         TA
#
#      PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition  SalePrice
# 2             Y   None   None        None       WD        Normal  12.317171
# 3             Y   None   None        None       WD       Abnorml  11.849405
# 4             Y   None   None        None       WD        Normal  12.429220
# 5             Y   None  MnPrv        Shed       WD        Normal  11.870607
# 7             Y   None   None        Shed       WD        Normal  12.206078
# ...         ...    ...    ...         ...      ...           ...        ...
# 1429          Y   None   None        None       WD        Normal  12.116700
# 1431          Y   None   None        None       WD        Normal  11.875838
# 1433          Y   None   None        None       WD        Normal  12.136192
# 1440          Y   None   None        None       WD        Normal  12.160034
# 1446          P   None   None        None       WD        Normal  11.969724
#
# [484 rows x 44 columns]), ('IR2',      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 12         RL   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 50         RL   Pave  None      IR2         Lvl    AllPub    Corner       Gtl
# 52         RM   Grvl  None      IR2         Bnk    AllPub    Corner       Mod
# 58         RL   Pave  None      IR2         HLS    AllPub   CulDSac       Gtl
# 86         RL   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 95         RL   Pave  None      IR2         Lvl    AllPub    Corner       Gtl
# 185        RM   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 213        RL   Pave  None      IR2         Lvl    AllPub   CulDSac       Gtl
# 249        RL   Pave  None      IR2         Low    AllPub   CulDSac       Sev
# 349        RL   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 355        RL   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 384        RL   Pave  None      IR2         Low    AllPub    Corner       Mod
# 400        RL   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 412        FV   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 414        RL   Pave  None      IR2         Lvl    AllPub   CulDSac       Gtl
# 435        RL   Pave  None      IR2         Lvl    AllPub   CulDSac       Gtl
# 558        RL   Pave  None      IR2         HLS    AllPub       FR2       Gtl
# 606        RL   Pave  None      IR2         Low    AllPub    Corner       Mod
# 661        RL   Pave  None      IR2         Lvl    AllPub   CulDSac       Gtl
# 664        RL   Pave  None      IR2         Lvl    AllPub   CulDSac       Gtl
# 681        RH   Pave  Pave      IR2         Bnk    AllPub    Inside       Gtl
# 684        RL   Pave  None      IR2         Lvl    AllPub   CulDSac       Gtl
# 687        FV   Pave  None      IR2         Lvl    AllPub       FR2       Gtl
# 699        FV   Pave  Pave      IR2         Lvl    AllPub    Inside       Gtl
# 706        RL   Pave  None      IR2         Low    AllPub   CulDSac       Sev
# 769        RL   Pave  None      IR2         HLS    AllPub   CulDSac       Mod
# 782        RL   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 815        RL   Pave  None      IR2         Lvl    AllPub   CulDSac       Gtl
# 828        RL   Pave  None      IR2         Low    AllPub   CulDSac       Sev
# 848        RL   Pave  None      IR2         Bnk    AllPub    Inside       Gtl
# 868        RL   Pave  None      IR2         Lvl    AllPub    Corner       Gtl
# 909        RL   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 934        RL   Pave  None      IR2         HLS    AllPub    Inside       Mod
# 1047       RL   Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 1057       RL   Pave  None      IR2         Lvl    AllPub       FR2       Gtl
# 1084       RL   Pave  None      IR2         Lvl    AllPub    Corner       Gtl
# 1180       RL   Pave  None      IR2         Lvl    AllPub    Corner       Gtl
# 1237       RL   Pave  None      IR2         Lvl    AllPub       FR2       Gtl
# 1318       RL   Pave  None      IR2         Lvl    AllPub   CulDSac       Gtl
# 1346       RL   Pave  None      IR2         Lvl    AllPub   CulDSac       Gtl
# 1369       RL   Pave  None      IR2         Lvl    AllPub       FR2       Gtl
#
#      Neighborhood Condition1  ... GarageFinish GarageQual GarageCond  \
# 12         Sawyer       Norm  ...          Unf         TA         TA
# 50        Gilbert       Norm  ...          Fin         TA         TA
# 52         IDOTRR       RRNn  ...          Unf         TA         TA
# 58        StoneBr       Norm  ...          Fin         TA         TA
# 86        Gilbert       Norm  ...          Fin         TA         TA
# 95        Gilbert       Norm  ...          Fin         TA         TA
# 185       OldTown     Artery  ...          Unf         Ex         TA
# 213       CollgCr       Norm  ...          Unf         TA         TA
# 249       ClearCr       Norm  ...          Fin         TA         TA
# 349       NridgHt       Norm  ...          Fin         TA         TA
# 355       CollgCr       Norm  ...          RFn         TA         TA
# 384       ClearCr      Feedr  ...          Fin         TA         TA
# 400       Veenker       Norm  ...          Fin         TA         TA
# 412       Somerst       Norm  ...          Fin         TA         TA
# 414       SawyerW       Norm  ...          Unf         TA         TA
# 435       CollgCr       PosN  ...          RFn         TA         TA
# 558       Gilbert       Norm  ...          Unf         TA         TA
# 606       CollgCr       Norm  ...          Unf         TA         TA
# 661       NoRidge       Norm  ...          RFn         TA         TA
# 664       Somerst       RRAn  ...          Fin         TA         TA
# 681         SWISU       Norm  ...          Unf         TA         TA
# 684       NoRidge       Norm  ...          Fin         TA         TA
# 687       Somerst       Norm  ...          Unf         TA         TA
# 699       Somerst       Norm  ...          RFn         TA         TA
# 706       ClearCr       Norm  ...          Unf         TA         TA
# 769       StoneBr       Norm  ...          Fin         TA         TA
# 782       CollgCr       Norm  ...          RFn         TA         TA
# 815       CollgCr       Norm  ...          RFn         TA         TA
# 828       ClearCr       Norm  ...          Fin         TA         TA
# 848       ClearCr       Norm  ...          Unf         Fa         TA
# 868       Gilbert      Feedr  ...          Unf         TA         TA
# 909       Gilbert       Norm  ...          Fin         TA         TA
# 934         NAmes       PosA  ...          RFn         TA         TA
# 1047      CollgCr       Norm  ...          Unf         TA         TA
# 1057      NoRidge       Norm  ...          Fin         TA         TA
# 1084      Gilbert       Norm  ...          Fin         TA         TA
# 1180       Timber       Norm  ...          Fin         TA         TA
# 1237      CollgCr       Norm  ...          Fin         TA         TA
# 1318      CollgCr       Norm  ...          RFn         TA         TA
# 1346       NWAmes       PosN  ...          RFn         Gd         TA
# 1369      CollgCr       Norm  ...          Fin         TA         TA
#
#      PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition  SalePrice
# 12            Y   None   None        None       WD        Normal  11.877576
# 50            Y   None   None        None       WD        Normal  12.083911
# 52            Y   None   None        None       WD        Normal  11.608245
# 58            Y   None   None        None      New       Partial  12.991756
# 86            Y   None   None        None       WD        Normal  12.066816
# 95            Y   None   None        Shed       WD        Normal  12.128117
# 185           Y   None  GdPrv        None       WD        Normal  13.071072
# 213           Y   None   None        None       WD        Normal  11.957618
# 249           Y   None   None        Shed       WD        Normal  12.531776
# 349           Y   None   None        None      New       Partial  12.988043
# 355           Y   None   None        None       WD        Normal  12.086732
# 384           Y   None   None        None       WD        Normal  12.388398
# 400           Y   None   None        None       WD        Normal  12.411056
# 412           Y   None   None        None      New       Partial  12.310437
# 414           Y   None   None        None       WD        Normal  12.337105
# 435           Y   None   None        None    ConLw        Normal  12.264346
# 558           Y   None   None        None       WD        Normal  12.072547
# 606           Y   None  GdPrv        None       WD        Normal  11.931642
# 661           Y   None   None        None       WD        Normal  12.904210
# 664           Y   None   None        None      New       Partial  12.955130
# 681           Y   None   None        None       WD       Abnorml  11.979392
# 684           Y   None   None        None       WD        Normal  12.305923
# 687           Y   None   None        None       WD        Normal  11.910365
# 699           Y   None   None        None       WD        Normal  12.185875
# 706           Y   None   None        None       WD        Normal  12.618186
# 769           Y   None   None        None       WD        Normal  13.195616
# 782           Y   None   None        None       WD        Normal  12.139404
# 815           Y   None   None        None       WD        Normal  12.323416
# 828           Y   None   None        None       WD       Abnorml  12.128117
# 848           Y   None   None        None       WD        Normal  12.388398
# 868           P   None   None        None       WD        Normal  12.037660
# 909           Y   None   None        None       WD        Normal  12.066816
# 934           Y   None   None        None       WD        Normal  12.396697
# 1047          Y   None   None        None       WD        Normal  11.884496
# 1057          Y   None   None        None       WD        Normal  12.421188
# 1084          Y   None   None        None       WD        Normal  12.141539
# 1180          Y   None  GdPrv        None       WD        Normal  12.429220
# 1237          Y   None   None        None       WD        Normal  12.180760
# 1318          Y   None   None        None       WD        Normal  12.524530
# 1346          Y   None   None        None       WD        Normal  12.478010
# 1369          Y   None   None        None       WD        Normal  12.354497
#
# [41 rows x 44 columns]), ('IR3',      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 264        RM   Pave  Grvl      IR3         Bnk    AllPub    Inside       Gtl
# 301        RL   Pave  None      IR3         Lvl    AllPub    Inside       Gtl
# 313        RL   Pave  None      IR3         Low    AllPub    Inside       Sev
# 1006       RL   Pave  None      IR3         Lvl    AllPub    Inside       Gtl
# 1107       RL   Pave  None      IR3         HLS    AllPub   CulDSac       Gtl
# 1127       RL   Pave  None      IR3         Lvl    AllPub    Corner       Gtl
# 1260       RL   Pave  None      IR3         Lvl    AllPub   CulDSac       Gtl
# 1298       RL   Pave  None      IR3         Bnk    AllPub    Corner       Gtl
# 1348       RL   Pave  None      IR3         Low    AllPub    Inside       Gtl
# 1430       RL   Pave  None      IR3         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1  ... GarageFinish GarageQual GarageCond  \
# 264       OldTown     Artery  ...          Unf         TA         TA
# 301       CollgCr       Norm  ...          Fin         TA         TA
# 313        Timber       Norm  ...          RFn         TA         TA
# 1006        NAmes       PosN  ...          Unf         TA         TA
# 1107      Gilbert       Norm  ...          RFn         TA         TA
# 1127      Gilbert       Norm  ...          Fin         TA         TA
# 1260      Gilbert       RRAn  ...          Fin         TA         TA
# 1298      Edwards      Feedr  ...          Fin         TA         TA
# 1348      SawyerW       Norm  ...          RFn         TA         TA
# 1430      Gilbert       RRAn  ...          Fin         TA         TA
#
#      PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition  SalePrice
# 264           N   None  None        None       WD        Normal  11.198228
# 301           Y   None  None        None       WD        Normal  12.495008
# 313           Y   None  None        None       WD        Normal  12.834684
# 1006          Y   None  None        None       WD        Normal  12.004574
# 1107          Y   None  None        None      New       Partial  12.523530
# 1127          Y   None  None        None       WD        Family  12.464587
# 1260          Y   None  None        None       WD        Normal  12.106258
# 1298          Y     Gd  None        None      New       Partial  11.982935
# 1348          Y   None  None        None       WD        Normal  12.278398
# 1430          Y   None  None        None       WD        Normal  12.165985
#
# [10 rows x 44 columns]), ('Reg',      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 6          RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 8          RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 9          RL   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1  ... GarageFinish GarageQual GarageCond  \
# 0         CollgCr       Norm  ...          RFn         TA         TA
# 1         Veenker      Feedr  ...          RFn         TA         TA
# 6         Somerst       Norm  ...          RFn         TA         TA
# 8         OldTown     Artery  ...          Unf         Fa         TA
# 9         BrkSide     Artery  ...          RFn         Gd         TA
# ...           ...        ...  ...          ...        ...        ...
# 1455      Gilbert       Norm  ...          RFn         TA         TA
# 1456       NWAmes       Norm  ...          Unf         TA         TA
# 1457      Crawfor       Norm  ...          RFn         TA         TA
# 1458        NAmes       Norm  ...          Unf         TA         TA
# 1459      Edwards       Norm  ...          Fin         TA         TA
#
#      PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition  SalePrice
# 0             Y   None   None        None       WD        Normal  12.247699
# 1             Y   None   None        None       WD        Normal  12.109016
# 6             Y   None   None        None       WD        Normal  12.634606
# 8             Y   None   None        None       WD       Abnorml  11.774528
# 9             Y   None   None        None       WD        Normal  11.678448
# ...         ...    ...    ...         ...      ...           ...        ...
# 1455          Y   None   None        None       WD        Normal  12.072547
# 1456          Y   None  MnPrv        None       WD        Normal  12.254868
# 1457          Y   None  GdPrv        Shed       WD        Normal  12.493133
# 1458          Y   None   None        None       WD        Normal  11.864469
# 1459          Y   None   None        None       WD        Normal  11.901590
#
# [925 rows x 44 columns])]
# [('IR1', 2       12.317171
# 3       11.849405
# 4       12.429220
# 5       11.870607
# 7       12.206078
#           ...
# 1429    12.116700
# 1431    11.875838
# 1433    12.136192
# 1440    12.160034
# 1446    11.969724
# Name: SalePrice, Length: 484, dtype: float64), ('IR2', 12      11.877576
# 50      12.083911
# 52      11.608245
# 58      12.991756
# 86      12.066816
# 95      12.128117
# 185     13.071072
# 213     11.957618
# 249     12.531776
# 349     12.988043
# 355     12.086732
# 384     12.388398
# 400     12.411056
# 412     12.310437
# 414     12.337105
# 435     12.264346
# 558     12.072547
# 606     11.931642
# 661     12.904210
# 664     12.955130
# 681     11.979392
# 684     12.305923
# 687     11.910365
# 699     12.185875
# 706     12.618186
# 769     13.195616
# 782     12.139404
# 815     12.323416
# 828     12.128117
# 848     12.388398
# 868     12.037660
# 909     12.066816
# 934     12.396697
# 1047    11.884496
# 1057    12.421188
# 1084    12.141539
# 1180    12.429220
# 1237    12.180760
# 1318    12.524530
# 1346    12.478010
# 1369    12.354497
# Name: SalePrice, dtype: float64), ('IR3', 264     11.198228
# 301     12.495008
# 313     12.834684
# 1006    12.004574
# 1107    12.523530
# 1127    12.464587
# 1260    12.106258
# 1298    11.982935
# 1348    12.278398
# 1430    12.165985
# Name: SalePrice, dtype: float64), ('Reg', 0       12.247699
# 1       12.109016
# 6       12.634606
# 8       11.774528
# 9       11.678448
#           ...
# 1455    12.072547
# 1456    12.254868
# 1457    12.493133
# 1458    11.864469
# 1459    11.901590
# Name: SalePrice, Length: 925, dtype: float64)]
# LotShape
# IR1    12.163471
# IR2    12.318455
# IR3    12.205419
# Reg    11.936101
# Name: SalePrice, dtype: float64
#   LotShape  SalePrice
# 0      IR1  12.163471
# 1      IR2  12.318455
# 2      IR3  12.205419
# 3      Reg  11.936101
#   LotShape  LotShape_mean
# 0      IR1      12.163471
# 1      IR2      12.318455
# 2      IR3      12.205419
# 3      Reg      11.936101

# %%
# 均值編碼 + 線性迴歸
data = pd.concat([df[:train_num], train_Y], axis=1)
for c in df.columns:
    mean_df = data.groupby([c])['SalePrice'].mean().reset_index()
    mean_df.columns = [c, f'{c}_mean'] #修改mean_df的欄位名稱
    data = pd.merge(data, mean_df, on=c, how='left')
    data = data.drop([c] , axis=1)
data = data.drop(['SalePrice'] , axis=1)
estimator = LinearRegression()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, data, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.7624230403716964
# time : 0.015616893768310547 sec

# %%
# 對照組 : 標籤編碼 + 梯度提升樹
df_temp = pd.DataFrame()
for c in df.columns:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
train_X = df_temp[:train_num]
estimator = GradientBoostingRegressor()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, train_X, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.7779834360413026
# time : 0.9351530075073242 sec

# %%
# 均值編碼 + 梯度提升樹
data = pd.concat([df[:train_num], train_Y], axis=1)
for c in df.columns:
    mean_df = data.groupby([c])['SalePrice'].mean().reset_index()
    mean_df.columns = [c, f'{c}_mean']
    data = pd.merge(data, mean_df, on=c, how='left')
    data = data.drop([c] , axis=1)
data = data.drop(['SalePrice'] , axis=1)
estimator = GradientBoostingRegressor()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, data, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.8056383779677688
# time : 0.7625489234924316 sec

# %% [markdown]
# # 作業1
# * 請仿照範例，將鐵達尼範例中的類別型特徵改用均值編碼實作一次
#
# # 作業2
# * 觀察鐵達尼生存預測中，均值編碼與標籤編碼兩者比較，哪一個效果比較好? 可能的原因是什麼?
